# %%
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %%
# !pip install nvidia-smi
# Out:
# Requirement already satisfied: nvidia-smi in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (0.1.3)
# Requirement already satisfied: numpy>=1.16.2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nvidia-smi) (1.25.0)
# Requirement already satisfied: six>=1.12.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nvidia-smi) (1.16.0)
# Requirement already satisfied: sorcery>=0.1.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nvidia-smi) (0.2.2)
# Requirement already satisfied: pytest>=4.3.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nvidia-smi) (7.3.2)
# Requirement already satisfied: iniconfig in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from pytest>=4.3.1->nvidia-smi) (2.0.0)
# Requirement already satisfied: packaging in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from pytest>=4.3.1->nvidia-smi) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from pytest>=4.3.1->nvidia-smi) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from pytest>=4.3.1->nvidia-smi) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from pytest>=4.3.1->nvidia-smi) (2.0.1)
# Requirement already satisfied: executing in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sorcery>=0.1.0->nvidia-smi) (1.2.0)
# Requirement already satisfied: littleutils>=0.2.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sorcery>=0.1.0->nvidia-smi) (0.2.2)
# Requirement already satisfied: asttokens in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sorcery>=0.1.0->nvidia-smi) (2.2.1)
# Requirement already satisfied: wrapt in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sorcery>=0.1.0->nvidia-smi) (1.15.0)

# %%
# !pip install transformers[sentencepiece] datasets sacrebleu rouge_score py7zr -q
# Out:
# zsh:1: no matches found: transformers[sentencepiece]

# %%
pip install py7zr
# Out:
# Requirement already satisfied: py7zr in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (0.20.5)
# Requirement already satisfied: texttable in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (1.6.7)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (3.18.0)
# Requirement already satisfied: pyzstd>=0.14.4 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (0.15.8)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (1.0.0)
# Requirement already satisfied: pybcj>=0.6.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (1.0.1)
# Requirement already satisfied: multivolumefile>=0.2.3 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (0.2.3)
# Requirement already satisfied: brotli>=1.0.9 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (1.0.9)
# Requirement already satisfied: inflate64>=0.3.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (0.3.1)
# Requirement already satisfied: psutil in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from py7zr) (5.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: portalocker in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sacrebleu) (2.7.0)
# Requirement already satisfied: regex in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sacrebleu) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sacrebleu) (1.25.0)
# Requirement already satisfied: colorama in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sacrebleu) (4.9.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from rouge-score) (1.25.0)
# Requirement already satisfied: six>=1.14.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nltk->rouge-score) (8.1.3)
# Requirement already satisfied: joblib in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nltk->rouge-score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nltk->rouge-score) (2023.6.3)
# Requirement already satisfied: tqdm in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from nltk->rouge-score) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dataset
# Out:
# Requirement already satisfied: dataset in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: sqlalchemy<2.0.0,>=1.3.2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from dataset) (1.4.48)
# Requirement already satisfied: alembic>=0.6.2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from dataset) (1.11.1)
# Requirement already satisfied: banal>=1.0.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from dataset) (1.0.6)
# Requirement already satisfied: Mako in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from alembic>=0.6.2->dataset) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from alembic>=0.6.2->dataset) (4.6.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from Mako->alembic>=0.6.2->dataset) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (4.30.2)
# Requirement already satisfied: filelock in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (2023.5.7)

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (0.1.99)

# %%
# !pip install --upgrade accelerate
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate
# Out:
# Requirement already satisfied: accelerate in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: filelock in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (4.6.3)
# Requirement already satisfied: sympy in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Found existing installation: transformers 4.30.2
# Uninstalling transformers-4.30.2:
#   Successfully uninstalled transformers-4.30.2
# Found existing installation: accelerate 0.20.3
# Uninstalling accelerate-0.20.3:
#   Successfully uninstalled accelerate-0.20.3
# Collecting transformers
#   Using cached transformers-4.30.2-py3-none-any.whl (7.2 MB)
# Collecting accelerate
#   Using cached accelerate-0.20.3-py3-none-any.whl (227 kB)
# Requirement already satisfied: filelock in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.6.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: fsspec in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: sympy in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Installing collected packages: transformers, accelerate
# Successfully installed accelerate-0.20.3 transformers-4.30.2

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset, load_from_disk
import matplotlib.pyplot as plt
from datasets import load_dataset
import pandas as pd
from datasets import load_dataset, load_metric

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

import nltk
from nltk.tokenize import sent_tokenize

from tqdm import tqdm
import torch

nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /Users/dhiraj-
# [nltk_data]     mac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
model_ckpt = "google/pegasus-cnn_dailymail"

tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt).to(device)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 88.0/88.0 [00:00<00:00, 133kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 1.12k/1.12k [00:00<00:00, 5.86MB/s]
# Downloading (…)ve/main/spiece.model: 100%|██████████| 1.91M/1.91M [00:00<00:00, 4.44MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 65.0/65.0 [00:00<00:00, 150kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 2.28G/2.28G [06:06<00:00, 6.20MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 280/280 [00:00<00:00, 463kB/s]

# %%
#dowload & unzip data

# !wget https://github.com/entbappy/Branching-tutorial/raw/master/summarizer-data.zip
# !unzip summarizer-data.zip
# Out:
# --2023-06-17 22:59:04--  https://github.com/entbappy/Branching-tutorial/raw/master/summarizer-data.zip
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/entbappy/Branching-tutorial/master/summarizer-data.zip [following]
# --2023-06-17 22:59:04--  https://raw.githubusercontent.com/entbappy/Branching-tutorial/master/summarizer-data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7903594 (7.5M) [application/zip]
# Saving to: ‘summarizer-data.zip’
#
# summarizer-data.zip 100%[===================>]   7.54M  6.76MB/s    in 1.1s
#
# 2023-06-17 22:59:06 (6.76 MB/s) - ‘summarizer-data.zip’ saved [7903594/7903594]
#
# Archive:  summarizer-data.zip
#   inflating: samsum-test.csv
#   inflating: samsum-train.csv
#   inflating: samsum-validation.csv
#    creating: samsum_dataset/
#  extracting: samsum_dataset/dataset_dict.json
#    creating: samsum_dataset/test/
#   inflating: samsum_dataset/test/data-00000-of-00001.arrow
#   inflating: samsum_dataset/test/dataset_info.json
#   inflating: samsum_dataset/test/state.json
#    creating: samsum_dataset/train/
#   inflating: samsum_dataset/train/data-00000-of-00001.arrow
#   inflating: samsum_dataset/train/dataset_info.json
#   inflating: samsum_dataset/train/state.json
#    creating: samsum_dataset/validation/
#   inflating: samsum_dataset/validation/data-00000-of-00001.arrow
#   inflating: samsum_dataset/validation/dataset_info.json
#   inflating: samsum_dataset/validation/state.json

# %%
dataset_samsum = load_from_disk('samsum_dataset')
dataset_samsum
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 14732
#     })
#     test: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 819
#     })
#     validation: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 818
#     })
# })

# %%
split_lengths = [len(dataset_samsum[split])for split in dataset_samsum]

print(f"Split lengths: {split_lengths}")
print(f"Features: {dataset_samsum['train'].column_names}")
print("\nDialogue:")

print(dataset_samsum["test"][1]["dialogue"])

print("\nSummary:")

print(dataset_samsum["test"][1]["summary"])
# Out:
# Split lengths: [14732, 819, 818]
# Features: ['id', 'dialogue', 'summary']
#
# Dialogue:
# Eric: MACHINE!
# Rob: That's so gr8!
# Eric: I know! And shows how Americans see Russian ;)
# Rob: And it's really funny!
# Eric: I know! I especially like the train part!
# Rob: Hahaha! No one talks to the machine like that!
# Eric: Is this his only stand-up?
# Rob: Idk. I'll check.
# Eric: Sure.
# Rob: Turns out no! There are some of his stand-ups on youtube.
# Eric: Gr8! I'll watch them now!
# Rob: Me too!
# Eric: MACHINE!
# Rob: MACHINE!
# Eric: TTYL?
# Rob: Sure :)
#
# Summary:
# Eric and Rob are going to watch a stand-up on youtube.

# %%
def convert_examples_to_features(example_batch):
    input_encodings = tokenizer(example_batch['dialogue'] , max_length = 1024, truncation = True )

    with tokenizer.as_target_tokenizer():
        target_encodings = tokenizer(example_batch['summary'], max_length = 128, truncation = True )

    return {
        'input_ids' : input_encodings['input_ids'],
        'attention_mask': input_encodings['attention_mask'],
        'labels': target_encodings['input_ids']
    }

# %%
dataset_samsum_pt = dataset_samsum.map(convert_examples_to_features, batched = True)
# Out:
# Map:   0%|          | 0/14732 [00:00<?, ? examples/s]/Users/dhiraj-mac/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3619: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(

# %%
dataset_samsum_pt["train"]
# Out:
# Dataset({
#     features: ['id', 'dialogue', 'summary', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 14732
# })

# %%
# Training

from transformers import DataCollatorForSeq2Seq

seq2seq_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model_pegasus)

# %%
from transformers import TrainingArguments, Trainer

trainer_args = TrainingArguments(
    output_dir='pegasus-samsum', num_train_epochs=1, warmup_steps=500,
    per_device_train_batch_size=1, per_device_eval_batch_size=1,
    weight_decay=0.01, logging_steps=10,
    evaluation_strategy='steps', eval_steps=500, save_steps=1e6,
    gradient_accumulation_steps=16
)

# %%
trainer = Trainer(model=model_pegasus, args=trainer_args,
                  tokenizer=tokenizer, data_collator=seq2seq_data_collator,
                  train_dataset=dataset_samsum_pt["test"],
                  eval_dataset=dataset_samsum_pt["validation"])

# %%
trainer.train()
# Out:
#   0%|          | 0/51 [00:17<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 trainer.train()
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/trainer.py:1645, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1640     self.model_wrapped = self.model
#    1642 inner_training_loop = find_executable_batch_size(
#    1643     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1644 )
# -> 1645 return inner_training_loop(
#    1646     args=args,
#    1647     resume_from_checkpoint=resume_from_checkpoint,
#    1648     trial=trial,
#    1649     ignore_keys_for_eval=ignore_keys_for_eval,
#    1650 )
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/trainer.py:1938, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1935     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1937 with self.accelerator.accumulate(model):
# -> 1938     tr_loss_step = self.training_step(model, inputs)
#    1940 if (
#    1941     args.logging_nan_inf_filter
#    1942     and not is_torch_tpu_available()
#    1943     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1944 ):
#    1945     # if loss is nan or inf simply add the average of previous logged losses
#    1946     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/trainer.py:2759, in Trainer.training_step(self, model, inputs)
#    2756     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2758 with self.compute_loss_context_manager():
# -> 2759     loss = self.compute_loss(model, inputs)
#    2761 if self.args.n_gpu > 1:
#    2762     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/trainer.py:2784, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2782 else:
#    2783     labels = None
# -> 2784 outputs = model(**inputs)
#    2785 # Save past state if it exists
#    2786 # TODO: this needs to be fixed and made cleaner later.
#    2787 if self.args.past_index >= 0:
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/models/pegasus/modeling_pegasus.py:1416, in PegasusForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1411     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1412         decoder_input_ids = shift_tokens_right(
#    1413             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1414         )
# -> 1416 outputs = self.model(
#    1417     input_ids,
#    1418     attention_mask=attention_mask,
#    1419     decoder_input_ids=decoder_input_ids,
#    1420     encoder_outputs=encoder_outputs,
#    1421     decoder_attention_mask=decoder_attention_mask,
#    1422     head_mask=head_mask,
#    1423     decoder_head_mask=decoder_head_mask,
#    1424     cross_attn_head_mask=cross_attn_head_mask,
#    1425     past_key_values=past_key_values,
#    1426     inputs_embeds=inputs_embeds,
#    1427     decoder_inputs_embeds=decoder_inputs_embeds,
#    1428     use_cache=use_cache,
#    1429     output_attentions=output_attentions,
#    1430     output_hidden_states=output_hidden_states,
#    1431     return_dict=return_dict,
#    1432 )
#    1433 lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#    1435 masked_lm_loss = None
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/models/pegasus/modeling_pegasus.py:1253, in PegasusModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1250 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1252 if encoder_outputs is None:
# -> 1253     encoder_outputs = self.encoder(
#    1254         input_ids=input_ids,
#    1255         attention_mask=attention_mask,
#    1256         head_mask=head_mask,
#    1257         inputs_embeds=inputs_embeds,
#    1258         output_attentions=output_attentions,
#    1259         output_hidden_states=output_hidden_states,
#    1260         return_dict=return_dict,
#    1261     )
#    1262 # If the user passed a tuple for encoder_outputs, we wrap it in a BaseModelOutput when return_dict=True
#    1263 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/transformers/models/pegasus/modeling_pegasus.py:769, in PegasusEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     766     raise ValueError("You have to specify either input_ids or inputs_embeds")
#     768 if inputs_embeds is None:
# --> 769     inputs_embeds = self.embed_tokens(input_ids) * self.embed_scale
#     771 embed_pos = self.embed_positions(input_shape)
#     773 hidden_states = inputs_embeds + embed_pos
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/torch/nn/modules/sparse.py:162, in Embedding.forward(self, input)
#     161 def forward(self, input: Tensor) -> Tensor:
# --> 162     return F.embedding(
#     163         input, self.weight, self.padding_idx, self.max_norm,
#     164         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/Work/Project/Text-Summarization-Project/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2210, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2204     # Note [embedding_renorm set_grad_enabled]
#    2205     # XXX: equivalent to
#    2206     # with torch.no_grad():
#    2207     #   torch.embedding_renorm_
#    2208     # remove once script supports set_grad_enabled
#    2209     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Placeholder storage has not been allocated on MPS device!

# %%
# Evaluation

def generate_batch_sized_chunks(list_of_elements, batch_size):
    """split the dataset into smaller batches that we can process simultaneously
    Yield successive batch-sized chunks from list_of_elements."""
    for i in range(0, len(list_of_elements), batch_size):
        yield list_of_elements[i : i + batch_size]



def calculate_metric_on_test_ds(dataset, metric, model, tokenizer,
                               batch_size=16, device=device,
                               column_text="article",
                               column_summary="highlights"):
    article_batches = list(generate_batch_sized_chunks(dataset[column_text], batch_size))
    target_batches = list(generate_batch_sized_chunks(dataset[column_summary], batch_size))

    for article_batch, target_batch in tqdm(
        zip(article_batches, target_batches), total=len(article_batches)):

        inputs = tokenizer(article_batch, max_length=1024,  truncation=True,
                        padding="max_length", return_tensors="pt")

        summaries = model.generate(input_ids=inputs["input_ids"].to(device),
                         attention_mask=inputs["attention_mask"].to(device),
                         length_penalty=0.8, num_beams=8, max_length=128)
        ''' parameter for length penalty ensures that the model does not generate sequences that are too long. '''

        # Finally, we decode the generated texts,
        # replace the  token, and add the decoded texts with the references to the metric.
        decoded_summaries = [tokenizer.decode(s, skip_special_tokens=True,
                                clean_up_tokenization_spaces=True)
               for s in summaries]

        decoded_summaries = [d.replace("", " ") for d in decoded_summaries]


        metric.add_batch(predictions=decoded_summaries, references=target_batch)

    #  Finally compute and return the ROUGE scores.
    score = metric.compute()
    return score

# %%
rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
rouge_metric = load_metric('rouge')
# Out:
# <ipython-input-18-f252dc652019>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge_metric = load_metric('rouge')
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
score = calculate_metric_on_test_ds(
    dataset_samsum['test'][0:10], rouge_metric, trainer.model, tokenizer, batch_size = 2, column_text = 'dialogue', column_summary= 'summary'
)

rouge_dict = dict((rn, score[rn].mid.fmeasure ) for rn in rouge_names )

pd.DataFrame(rouge_dict, index = [f'pegasus'] )
# Out:
# 100%|██████████| 5/5 [00:26<00:00,  5.27s/it]
#            rouge1  rouge2   rougeL  rougeLsum
# pegasus  0.022373     0.0  0.02209    0.02219

# %%
## Save model
model_pegasus.save_pretrained("pegasus-samsum-model")

# %%
## Save tokenizer
tokenizer.save_pretrained("tokenizer")
# Out:
# ('tokenizer/tokenizer_config.json',
#  'tokenizer/special_tokens_map.json',
#  'tokenizer/spiece.model',
#  'tokenizer/added_tokens.json',
#  'tokenizer/tokenizer.json')

# %%
#Load

tokenizer = AutoTokenizer.from_pretrained("/content/tokenizer")

# %%
#Prediction

gen_kwargs = {"length_penalty": 0.8, "num_beams":8, "max_length": 128}



sample_text = dataset_samsum["test"][0]["dialogue"]

reference = dataset_samsum["test"][0]["summary"]

pipe = pipeline("summarization", model="pegasus-samsum-model",tokenizer=tokenizer)

##
print("Dialogue:")
print(sample_text)


print("\nReference Summary:")
print(reference)


print("\nModel Summary:")
print(pipe(sample_text, **gen_kwargs)[0]["summary_text"])
# Out:
# Your max_length is set to 128, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Dialogue:
# Hannah: Hey, do you have Betty's number?
# Amanda: Lemme check
# Hannah: <file_gif>
# Amanda: Sorry, can't find it.
# Amanda: Ask Larry
# Amanda: He called her last time we were at the park together
# Hannah: I don't know him well
# Hannah: <file_gif>
# Amanda: Don't be shy, he's very nice
# Hannah: If you say so..
# Hannah: I'd rather you texted him
# Amanda: Just text him 🙂
# Hannah: Urgh.. Alright
# Hannah: Bye
# Amanda: Bye bye
#
# Reference Summary:
# Hannah needs Betty's number but Amanda doesn't have it. She needs to contact Larry.
#
# Model Summary:
# Amanda: Ask Larry Amanda: He called her last time we were at the park together .<n>Hannah: I'd rather you texted him .<n>Amanda: Just text him .
